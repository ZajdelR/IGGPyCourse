# %% [markdown]
# <img src="./src/header.png">

# %% [markdown]
# ----
#
# # Moduł 2 - Ćwiczenia
# ---

# %% [markdown]
# ## Cele ćwiczeń
# - utrwalenie pracy z typami liczbowymi i tekstowymi;
# - ćwiczenie operacji na listach, krotkach, zakresach oraz boolach;
# - przygotowanie mini‑narzędzi przydatnych przy dalszych modułach (np. operacje na nazwach plików i parametrach misji).
#
# Poniżej znajdziesz 18 zadań – od prostych obliczeń po mini‑skrypty na sekwencjach. Wiele z nich odwołuje się do realnych przypadków użycia (daty obserwacji, prognozy zachmurzenia, itp.).

# %% [markdown]
# ----
#
# ## Zad 1 — Typy i `type()`
# ---
#
# Zadeklaruj zmienne reprezentujące liczbę obserwacji (`42`), nazwę misji (`'Sentinel-2'`) i zachmurzenie (`0.23`). Wypisz typ każdej z nich. Następnie zmień zachmurzenie na napis `'0.23'`, ponownie wypisz typ i rzutuj go z powrotem na `float`.

# %% [markdown]
# ----
#
# ## Zad 2 — Pole koła i `math.pi`
# ---
#
# Użyj `math.pi` do obliczenia pola i obwodu koła o promieniu 15 km. Wynik sformatuj w komunikacie `f"R=15 km -> pole={area:.2f} km^2"`. Powtórz obliczenia z własną wartością `pi=3.14` i porównaj różnice.

# %% [markdown]
# ----
#
# ## Zad 3 — Parsowanie tekstu na liczbę
# ---
#
# Masz napis `alt = 'Wysokość: 786 km'`. Za pomocą metod `str.split` / `str.strip` wydziel liczbę, przekonwertuj ją na `int` i oblicz orbitę kołową: `EARTH_RADIUS + alt`.

# %% [markdown]
# ----
#
# ## Zad 4 — F-string i ścieżki plików
# ---
#
# Zbuduj funkcję, która przyjmuje nazwę misji (`'S2A'`) i datę (`'2025-03-01'`) i zwraca ścieżkę `data/S2A/2025-03-01/scene.tif` wykorzystując f-string. Dodaj sprawdzenie, czy wynik kończy się ukośnikiem (`/`).

# %% [markdown]
# ----
#
# ## Zad 5 — Znaki ucieczki i wielolinijkowy tekst
# ---
#
# Stwórz napis dokumentacji, który zawiera cudzysłowy i nowe linie (np. opis parametru). Użyj potrójnych cudzysłowów i sekwencji `\n` / `\t`, aby uzyskać czytelny output.

# %% [markdown]
# ----
#
# ## Zad 6 — Operacje na napisach
# ---
#
# Dla zmiennej `sensor = 'MultiSpectral Instrument'` wykonaj: `sensor.upper()`, `sensor.replace(' ', '_')`, sprawdź czy kończy się na `Instrument` (`sensor.endswith(...)`) i wypisz liczbę liter `i`.

# %% [markdown]
# ----
#
# ## Zad 7 — Slicing nazw scen
# ---
#
# Mając listę `scenes = ['S2A_20250301T095021', 'S2B_20250305T095021']` wyciągnij z każdego elementu: (a) nazwę misji (`S2A`), (b) datę (`20250301`). Użyj wycinków i zapisz wyniki w nowych listach.

# %% [markdown]
# ----
#
# ## Zad 8 — Listy i mutowalność
# ---
#
# Stwórz listę `tasks = ['download', 'filter', 'report']`. Zrób jej kopię płytką (`copy_tasks = tasks[:]`) oraz przypisanie referencji (`ref_tasks = tasks`). Dodaj element `'archive'` tylko do jednej z nich i pokaż, która lista uległa zmianie. Wyjaśnij dlaczego.

# %% [markdown]
# ----
#
# ## Zad 9 — Krotki jako stałe konfiguracje
# ---
#
# Zbuduj krotkę `station = ('WRO', 51.11, 17.02)` i pokaż, że nie można jej zmieniać (spróbuj przypisać nową wartość). Następnie rozpakuj krotkę na zmienne `code, lat, lon` i wypisz sformatowany komunikat o stacji.

# %% [markdown]
# ----
#
# ## Zad 10 — Lista scen i filtry boolowskie
# ---
#
# Masz listę zachmurzeń `clouds = [0.12, 0.45, 0.05, 0.32]`. Utwórz drugą listę boolowską wskazującą, które sceny spełniają warunek `< 0.2`. Skorzystaj z pętli lub list comprehension. Podaj także indeksy scen zaakceptowanych.

# %% [markdown]
# ----
#
# ## Zad 11 — `range` i generowanie indeksów
# ---
#
# Stwórz listę z numerami minut co 5 minut w pierwszej godzinie (`0,5,10,...,55`) używając `range`. Następnie wykorzystaj `range` w pętli do wypisania wiadomości `Minute XX: sprawdź status instrumentu`.

# %% [markdown]
# ----
#
# ## Zad 12 — Średnia i `sum`
# ---
#
# Z listy pomiarów temperatur `temps = [19.5, 20.1, 18.9, 19.8]` oblicz średnią z wykorzystaniem `sum` i `len`. Sformatuj wynik do jednej cyfry po przecinku.

# %% [markdown]
# ----
#
# ## Zad 13 — `join` i `split`
# ---
#
# Z krotki `('S2A', '2025', '03', '01')` stwórz napis `S2A-2025-03-01` korzystając z `str.join`. Odwróć operację: rozbij napis na listę i przypisz elementy do osobnych zmiennych.

# %% [markdown]
# ----
#
# ## Zad 14 — Wyszukiwanie w tekście
# ---
#
# Użyj krótkiego akapitu (np. fragmentu inwokacji). Policz wystąpienia litery `a` (w obu wielkościach), sprawdź, czy słowo `'Litwo'` występuje oraz zamień wszystkie przecinki na średniki.

# %% [markdown]
# ----
#
# ## Zad 15 — Funkcja zwracająca `bool`
# ---
#
# Napisz funkcję `is_valid_scene(name)` zwracającą `True`, jeśli napis zaczyna się od `'S2'` i ma długość 20 znaków. Przetestuj ją na kilku przykładach i pokaż, jak wynik boolowski wykorzystać w instrukcji `if`.

# %% [markdown]
# ----
#
# ## Zad 16 — `math` i `cmath`
# ---
#
# Zaimportuj `math` i oblicz promień orbity: `sqrt((R+h)**3 / MU)`. Następnie użyj `cmath.sqrt(-1)` aby pokazać, że operacje na liczbach zespolonych również są możliwe (zwróć uwagę na typ wyniku).

# %% [markdown]
# ----
#
# ## Zad 17 — Konwersje list/krotek
# ---
#
# Konwertuj napis `'S2A,Sentinel-2A,MSI'` na listę pól (rozdzielając po przecinku), a następnie zamień tę listę na krotkę. Wyjaśnij, dlaczego w niektórych sytuacjach chcesz zablokować modyfikacje (użyj krotki).

# %% [markdown]
# ----
#
# ## Zad 18 — Mini raport z `zip`
# ---
#
# Przygotuj listę misji `missions = ['S2A', 'S2B', 'L8']` i równoległą listę liczb obserwacji `[12, 9, 7]`. Użyj `zip` do stworzenia listy krotek i wypisz raport w formie `S2A -> 12 obserwacji`. Wskaż, który typ danych (lista krotek vs słownik) byłby wygodniejszy w dalszej analizie i dlaczego.

# %% [markdown]
# ----
#
# ## Zad 19 — Walidacja wejścia
# ---
#
# Napisz krótki skrypt, który pyta użytkownika o liczbę scen do przetworzenia. Funkcja `input()` zwraca napis – skonwertuj go na `int`, sprawdź czy wartość jest większa od zera i wypisz komunikat. Obsłuż sytuację, w której wpisano nie-liczbę (wyświetl informację o błędnym typie).

# %% [markdown]
# ----
#
# ## Zad 20 — Referencje i `id()`
# ---
#
# Utwórz listę `coords = [10, 20]`, przypisz ją do `coords_copy = coords`, a następnie do `coords_clone = coords.copy()`. Zmodyfikuj jeden z elementów i pokaż `id()` każdego obiektu. Wytłumacz różnicę między kopiowaniem referencji a tworzeniem kopii.

# %% [markdown]
# ----
#
# ## Zad 1
# ---
#
# Zapoznaj się z działaniem środowiska Jupyter Notebook

# %% [markdown]
# ----
#
# ## Zad 2
# ---
#
# Stwórz zmienną o nazwie `pi` i wartości 3.14. Wykorzystaj ją do obliczenia pola koła o promieniu 12. Wynik wyświetl na ekran. Zrób to samo importując wartość pi z biblioteki math

# %% [markdown]
# ----
#
# ## Zad 3
# ---
#
# Wykorzystaj zmienną ‘pi’ z biblioteki math:
# - Przypisz wartość zmiennej ‘pi’ z biblioteki math do nowej zmiennej o nazwie ‘liczba_pi’
# - Zaimportuj zmienną pi bezpośrednio do programu, bez deklaracji nowej zmiennej
#     (2 sposoby)

# %% [markdown]
# ----
#
# ## Zad 4
# ---
#
# Korzystając z wbudowanej dokumentacji znajdź funkcję, która wyznacza licznik i mianownik ułamka zwykłego dowolnej liczby zmiennoprzecinkowej.
# - Wskazówka: `help(float)`*
# - Przetestuj jej działanie na kilku dowolnych przykładach.
# - Przetestuj działania na dowolnej liczbie niewymiernej np. pi lub pierwiastek z 3

# %% [markdown]
# ----
#
# ## Zad 5
# ---
#
# Sprawdź czy:
# - liczba pi zaimportowana z biblioteki math jest równa liczbie pi obliczonej dwoma dowolnymi metodami szybko zbieżnymi (https://pl.wikipedia.org/wiki/Pi#Wzory_szybko_zbie%C5%BCne)
# - liczba pi zaimportowana z biblioteki math jest „w przybliżeniu” równa liczbie pi obliczonej dwoma dowolnymi metodami szybko zbieżnymi

# %% [markdown]
# ----
#
# ## Zad 6
# ---
#
# Zdefiniuj dwie zmienne typu tekstowego i jedną całkowitą, np.
#
# ```
# a = "jeden"
# b = "dwa"
# c = 3
# ```
#
# Wykonaj następujące polecenia, następnie skomentuj wyniki:
#
# ```py
# a * b
# a + b
# a * c
# a + c
# a + str(c)
# ```

# %% [markdown]
# ----
#
# ## Zad 7
# ---
#
# Korzystając z dokumentacji klasy string (`help(str)`) zapoznaj się z definicjami funkcji: `strip()`, `isnumeric()` oraz `rjust()`. Zademonstruj ich działanie na dowolnych przykładach.

# %% [markdown]
# ----
#
# ## Zad 8
# ---
#
# Napisz skrypt, który wykona następujące czynności:
#
# - zmiennej `a` przypisze wartość podaną przez użytkownika np. `5`
# - zmiennej `b` przypisze wartość podaną przez użytkownika np. `3`
# - zmiennej `P` przypisze wartość `a*b`
# - wypisze na ekranie "Pole prostokąta o bokach `a` i `b` wynosi `P`." (gdzie w miejsce zmiennych zostaną wstawione odpowiednie wartości).
#
# ! Wykorzystaj funkcje input do wykonania tego ćwiczenia ! help(input)
# Zwróć uwagę jakiego typu zmienną zwraca funkcja input()

# %% [markdown]
# ----
#
# ## Zad 9
# ---
#
# Stwórz krotkę zawierającą pięć cyfr: 0, 1, 2, 3, 4 oraz pięć literałów słownych: "pięć", "sześć", "siedem", "osiem", "dziewięć".
# - Wydrukuj na ekranie trzy pierwsze elementy.
# - Wydrukuj na ekranie 2 ostatnie elementy.
# - Wydrukuj co drugi element (zaczynając od drugiego).
# - Wydrukuj elementy krotki zaczynając od ostatniego (odwrotnie)
# - Korzystając z funkcji *len* sprawdź ilość elementów w krotce oraz długość przedostatniego elementu.
# - Niech `x` oznacza nazwę krotki. Wykonaj:
# - x[:5] + (5, 6) + x[-3:]
# - x[:5], (5, 6), x[-3:]
# - porównaj i opisz otrzymane wyniki
# - Dodaj pusty literał słowny na koniec krotki 'x'. Czy możesz skorzystać z funkcji *append*?

# %% [markdown]
# ----
#
# ## Zad 10
# ---
#
# Stwórz listę studentów: Kasia, Basia, Marek, Darek.
#
# - Korzystając z metody *append* dodaj do listy Józka.
# - Korzystając z metody *extend* dodaj do listy Anię i Basię.
# - Posortuj alfabetycznie studentów.
# - Wypisz na ekranie:
#     - czwartego studenta na liście
#     - dwóch pierwszych studentów na liście
#     - dwóch ostatnich studentów na liście
# - Usuń wszystkie Basie z listy
# - Korzystając z funkcji *len* sprawdź ilość studentów.
# - Z ostatecznej listy studentów utwórz krotkę.

# %% [markdown]
# ----
#
# ## Zad 11
# ---
# Wykonaj polecenia:
# - Korzystając z `range` utwórz listę zawierającą wszystkie wielokrotności liczby 3 mniejsze od 100.
# - Korzystając z `del` usuń co trzeci element (zaczynając od piątego).
# - Sprawdź definicję funkcji wbudowanej *sum* (`help(sum)`). Wykorzystaj ją oraz funkcję *len*, aby wyliczyć średnią arytmetyczną otrzymanej listy.

# %% [markdown]
# ----
#
# ## Zad 12
# ---
# Stwórz krotkę: `('a', 'b', 'c', 'd')`
#
# - Zapoznaj się z dokumentacją funkcji `str.join`.
# - Wykonaj następujące polecenia (gdzie `x` to zmienna wskazująca na krotkę):
#
# ```py
# "".join(x)
# " ".join(x)
# ", ".join(x)
# ```
#
# - Wydrukuj na ekranie 100 zer oddzielonych tabulacjami (spróbuj wykonać to w jednej lini).

# %% [markdown]
# ----
#
# ## Zad 13
# ---
#
# Stwórz obiekt przechowujący inwokację Pana Tadeusza pod zmienną `inwokacja`
#
# ```
# inwokacja = """Litwo! Ojczyzno moja! Ty jesteś jak zdrowie,
# Ile cię trzeba cenić, ten tylko się dowie,
# Kto cię stracił. Dziś piękność twą w całej ozdobie
# Widzę i opisuję, bo tęsknię po tobie
# Panno święta, co Jasnej bronisz Częstochowy
# I w Ostrej świecisz Bramie! Ty, co gród zamkowy
# Nowogródzki ochraniasz z jego wiernym ludem!
# Jak mnie dziecko do zdrowia powróciłaś cudem,
# Gdy od płaczącej matki pod Twoją opiekę
# Ofiarowany, martwą podniosłem powiekę
# I zaraz mogłem pieszo do Twych świątyń progu
# Iść za wrócone życie podziękować Bogu,
# Tak nas powrócisz cudem na Ojczyzny łono.
# Tymczasem przenoś moją duszę utęsknioną
# Do tych pagórków leśnych, do tych łąk zielonych,
# Szeroko nad błękitnym Niemnem rozciągnionych;
# Do tych pól malowanych zbożem rozmaitem,
# Wyzłacanych pszenicą, posrebrzanych żytem;
# Gdzie bursztynowy świerzop, gryka jak śnieg biała,
# Gdzie panieńskim rumieńcem dzięcielina pała,
# A wszystko przepasane jakby wstęgą, miedzą
# Zieloną, na niej z rzadka ciche grusze siedzą."""
# ```
#
# - Popraw zmienną `inwokacja`, aby tekst zaczynał się małą literą (załóżmy że nie wiesz jaka to litera).
# - Korzystając z funkcji *count* sprawdź, ile razy występuje spójnik "i".
# - Korzystając z funkcji *count* sprawdź, ile razy występuje litera "i" (niezależnie od wielkości).
# - Sprawdź, czy słowo "dziecko" występuje w tekście
# - Korzystając z funkcji *str.split*:
#     - stwórz listę wyrazów występujących w tekście (np. 30 słów => 30 elementów
#     - stwórz listę, której każdy element odpowiada jednej linijce tekstu (4 linie => 4 elementy)
#     - Popraw zmienną `inwokacja`, tak aby każda linijka tekstu zaczynała się małą literą.

# %% [markdown]
# ----
#
# ## Zad 14
# ---
# Zapoznaj się z dokumentacją funkcji *id*.
#
# - Wykonaj następujące polecenia:
#
# ```
# x = 2
# y = x
# print(x, y, id(x), id(y))
# y = 3
# print(x, y, id(x), id(y))
# ```
#
# - Wykonaj następujące polecenia:
#
# ```
# x = [1,2]
# y = x
# print(x, y, id(x), id(y))
# y[1] = 3
# print(x, y, id(x), id(y))
# ```
#
# - Wyjaśnij, dlaczego modyfikacja y w drugim przypadku zmieniła także x
