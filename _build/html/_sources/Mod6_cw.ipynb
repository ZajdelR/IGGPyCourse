# %% [markdown]
# <img src="./src/header.png">

# %% [markdown]
# ----
#
# # Moduł 6 - Ćwiczenia

# %%
# %matplotlib inline
import pandas as pd
import sys

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
titles = pd.read_csv('data/titles.csv', encoding='UTF-8')
titles.head()
# Out:
#                   title  year
# 0  Kantarou tsukiyo-uta  1952
# 1               Maynila  1946
# 2        The Sonora Kid  1927
# 3    Shelet al mohtalin  1972
# 4        Love in Jungle  1970

# %%
cast = pd.read_csv('data/cast.csv',index_col=None,encoding='UTF-8')
cast.tail()
# Out:
#                                     title  year                         name  \
# 3397715                           Foxtrot  1988            Lilja Þórisdóttir
# 3397716  Niceland (Population. 1.000.002)  2004    Sigríður Jóna Þórisdóttir
# 3397717                         Skammdegi  1985           Dalla Þórðardóttir
# 3397718                      U.S.S.S.S...  2003  Kristín Andrea Þórðardóttir
# 3397719                 Bye Bye Blue Bird  1999                 Rosa á Rógvu
#
#             type               character     n
# 3397715  actress                    Dóra  24.0
# 3397716  actress            Woman in Bus  26.0
# 3397717  actress           Hjúkrunarkona   9.0
# 3397718  actress  Afgr.dama á bensínstöð  17.0
# 3397719  actress       Pensionatværtinde   NaN

# %% [markdown]
# ### 1. Filtrowanie danych - oglądanie danych które spełniają jakieś kryteria

# %%
titles # pandas nie jest głupi i nie pokazuje wszystkiego co ma (...)
# Out:
#                         title  year
# 0        Kantarou tsukiyo-uta  1952
# 1                     Maynila  1946
# 2              The Sonora Kid  1927
# 3          Shelet al mohtalin  1972
# 4              Love in Jungle  1970
# ...                       ...   ...
# 226008            Cluny Brown  1946
# 226009        Sherlock Holmes  1932
# 226010  Telepathic Telephones  2014
# 226011       The Sandwich Man  1966
# 226012            Pratidhwani  1971
#
# [226013 rows x 2 columns]

# %%
titles.head()
# Out:
#                   title  year
# 0  Kantarou tsukiyo-uta  1952
# 1               Maynila  1946
# 2        The Sonora Kid  1927
# 3    Shelet al mohtalin  1972
# 4        Love in Jungle  1970

# %%
h = titles.head(10)
h
# Out:
#                      title  year
# 0     Kantarou tsukiyo-uta  1952
# 1                  Maynila  1946
# 2           The Sonora Kid  1927
# 3       Shelet al mohtalin  1972
# 4           Love in Jungle  1970
# 5  My Liedjie van Verlange  1975
# 6               The Banker  1989
# 7   Lo spirito del serchio  2009
# 8    Blinky Bill the Movie  2015
# 9         L'elisir d'amore  1947

# %%
#h['year'] == h.year

# %%
h[(h.year < 1980) | (h.year >= 1990)] # or -> |
# Out:
#                      title  year
# 0     Kantarou tsukiyo-uta  1952
# 1                  Maynila  1946
# 2           The Sonora Kid  1927
# 3       Shelet al mohtalin  1972
# 4           Love in Jungle  1970
# 5  My Liedjie van Verlange  1975
# 7   Lo spirito del serchio  2009
# 8    Blinky Bill the Movie  2015
# 9         L'elisir d'amore  1947

# %%
t = titles

# %%
t[t.title == 'Macbeth'] # random order
# Out:
#           title  year
# 35518   Macbeth  1916
# 36282   Macbeth  1998
# 36719   Macbeth  2018
# 59273   Macbeth  2006
# 64811   Macbeth  2003
# 65040   Macbeth  1948
# 70980   Macbeth  2012
# 110789  Macbeth  2009
# 112226  Macbeth  2013
# 165826  Macbeth  1997
# 188292  Macbeth  2014
# 191930  Macbeth  1913
# 193906  Macbeth  2017
# 207237  Macbeth  2004
# 208333  Macbeth  1987
# 213113  Macbeth  2015

# %%
t[t.title == 'Macbeth'].sort_values('year')
# Out:
#           title  year
# 191930  Macbeth  1913
# 35518   Macbeth  1916
# 65040   Macbeth  1948
# 208333  Macbeth  1987
# 165826  Macbeth  1997
# 36282   Macbeth  1998
# 64811   Macbeth  2003
# 207237  Macbeth  2004
# 59273   Macbeth  2006
# 110789  Macbeth  2009
# 70980   Macbeth  2012
# 112226  Macbeth  2013
# 188292  Macbeth  2014
# 213113  Macbeth  2015
# 193906  Macbeth  2017
# 36719   Macbeth  2018

# %%
h = cast.head()
h = h[h.n.notnull()] # nie zmienia niczego
h
# Out:
#                  title  year      name   type        character     n
# 0       Closet Monster  2015  Buffy #1  actor          Buffy 4  31.0
# 1      Suuri illusioni  1985    Homo $  actor           Guests  22.0
# 2  Battle of the Sexes  2017   $hutter  actor  Bobby Riggs Fan  10.0

# %% [markdown]
# ### Ile filmów znajduje się w bazie danych?

# %%
len(titles)
# Out:
# 226013

# %% [markdown]
# ### Jakie są najwcześniejsze dwa filmy wymienione w dataframe tytułów?

# %%
titles.sort_values('year').head(2)
# Out:
#                      title  year
# 71835           Miss Jerry  1894
# 136315  The Startled Lover  1898

# %%
titles.sort_values('year').head(2)
# Out:
#                      title  year
# 71835           Miss Jerry  1894
# 136315  The Startled Lover  1898

# %% [markdown]
# ### Ile filmów ma tytuł "Hamlet"?

# %%
len(titles[titles.title == 'Hamlet'])
# Out:
# 20

# %% [markdown]
# ### Ile filmów nosi tytuł "North by Northwest"?

# %% [markdown]
# ### Kiedy powstał pierwszy film pod tytułem "Hamlet"?

# %%
titles[titles.title == 'Hamlet'].sort_values('year').head(1)
# Out:
#          title  year
# 154133  Hamlet  1910

# %% [markdown]
# ### Wymień wszystkie filmy z serii "Treasure Island" od najwcześniejszego do najnowszego.

# %% [markdown]
# ### Ile filmów powstało w roku 1950?

# %% [markdown]
# ### Ile filmów powstało w roku 1960?

# %% [markdown]
# ### Ile filmów powstało od 1950 do 1959 roku?

# %% [markdown]
# ### W jakich latach ukazał się film pod tytułem "Batman"?

# %% [markdown]
# ### Ile było ról w filmie "Inception"?

# %%
c = cast
c[c.title == 'Inception']
# Out:
#              title  year                  name     type  \
# 90228    Inception  2010  Michael (III) August    actor
# 136913   Inception  2010          Peter Basham    actor
# 168897   Inception  2010          Tom Berenger    actor
# 181725   Inception  2010              Ken Bhan    actor
# 238644   Inception  2010        Virgile Bramly    actor
# ...            ...   ...                   ...      ...
# 3084390  Inception  2010            Ellen Page  actress
# 3136148  Inception  2010        Nicole Pulliam  actress
# 3161648  Inception  2010    Lisa (II) Reynolds  actress
# 3168008  Inception  2010         Talulah Riley  actress
# 3393649  Inception  2010        Shannon Welles  actress
#
#                      character     n
# 90228            LAX Passenger   NaN
# 136913   Fischer's Jet Captain  44.0
# 168897                Browning   8.0
# 181725        Mombasan Gambler   NaN
# 238644          Bridge Sub Con  29.0
# ...                        ...   ...
# 3084390                Ariadne   3.0
# 3136148          Lobby Sub Con  43.0
# 3161648          Private Nurse  48.0
# 3168008                 Blonde  25.0
# 3393649                Old Mal  51.0
#
# [78 rows x 6 columns]

# %% [markdown]
# ### Ile ról w filmie "Incepcja" NIE jest uszeregowanych według wartości "n"?

# %%
d = c[c.title == 'Inception']

# %%
len(d[d.n.isnull()])
# Out:
# 27

# %% [markdown]
# ### A ile ról w filmie "Inception" otrzymało wartość "n"?

# %% [markdown]
# ### Wyświetl obsadę "North by Northwest" w ich poprawnej kolejności "n", ignorując role, które nie zdobyły numerycznej wartości "n".

# %% [markdown]
# ### Wyświetl całą obsadę, w kolejności "n", filmu "Sleuth" z 1972 roku.

# %% [markdown]
# ### Ile osób zagrało rolę o nazwie "The Dude"?

# %%
c = cast
c = c[c.character == 'The Stranger']
c
# Out:
#                             title  year                       name     type  \
# 23933                       Theeb  2014  Hassan Mutlag Al-Maraiyeh    actor
# 32992              My Time to Die  2014       Vincent H. Alexander    actor
# 42785                      Hickok  2017               Terral Altom    actor
# 61880                    Get Mean  1975               Tony Anthony    actor
# 61882    Lo straniero di silenzio  1968               Tony Anthony    actor
# ...                           ...   ...                        ...      ...
# 2921021              The Stranger  1995                 Kathy Long  actress
# 2933723            Ever Since Eve  1921                Ethel Lynne  actress
# 3101273              Weitertanzen  2008             Rosa Maria Paz  actress
# 3246470                Motherland  1927            Dorinea Shirley  actress
# 3407463               The Seventh  2017  Kerry (II) Willison-Parry  actress
#
#             character    n
# 23933    The Stranger  2.0
# 32992    The Stranger  2.0
# 42785    The Stranger  NaN
# 61880    The Stranger  1.0
# 61882    The Stranger  1.0
# ...               ...  ...
# 2921021  The Stranger  1.0
# 2933723  The Stranger  7.0
# 3101273  The Stranger  NaN
# 3246470  The Stranger  NaN
# 3407463  The Stranger  NaN
#
# [170 rows x 6 columns]

# %%
len(c)
# Out:
# 170

# %%
c = cast
c = c[c.character == 'The Stranger'].name.unique()
len(c)
# Out:
# 160

# %% [markdown]
# ### Ile ról zagrał ?? w ciągu swojej kariery?

# %%
c = cast
c = c[c.name == 'Hugh Grant']
c
# Out:
#                                                     title  year        name  \
# 797410                                        About a Boy  2002  Hugh Grant
# 797411                                    American Dreamz  2006  Hugh Grant
# 797412                           An Awfully Big Adventure  1995  Hugh Grant
# 797413                                        Bitter Moon  1992  Hugh Grant
# 797414                              Bridget Jones's Diary  2001  Hugh Grant
# 797415                  Bridget Jones: The Edge of Reason  2004  Hugh Grant
# 797416                                        Cloud Atlas  2012  Hugh Grant
# 797417                                        Cloud Atlas  2012  Hugh Grant
# 797418                                        Cloud Atlas  2012  Hugh Grant
# 797419                                        Cloud Atlas  2012  Hugh Grant
# 797420                                        Cloud Atlas  2012  Hugh Grant
# 797421                                        Cloud Atlas  2012  Hugh Grant
# 797422                    Did You Hear About the Morgans?  2009  Hugh Grant
# %% [markdown]
# ### Wymień role drugoplanowe (mające n=2) grane przez ? w latach ?, w kolejności według roku.

# %%
c = cast
c = c[c.name == 'Hugh Grant']
c = c[c.year // 10 == 199]
c = c[c.n == 2]
c = c.sort_values('year')
c
# Out:
#                            title  year        name   type        character  \
# 797427                 Impromptu  1991  Hugh Grant  actor  Frederic Chopin
# 797412  An Awfully Big Adventure  1995  Hugh Grant  actor  Meredith Potter
# 797435              Notting Hill  1999  Hugh Grant  actor  William Thacker
#
#           n
# 797427  2.0
# 797412  2.0
# 797435  2.0

# %% [markdown]
# ### Wymień pierwszoplanowe role, które ? zagrał w latach dwutysięcznych w kolejności według roku.

# %%
c = cast
c = c[c.name == 'Hugh Grant']
c = c[c.year // 10 == 200]
c = c[c.n == 1]
c = c.sort_values('year')
c
# Out:
#                                   title  year        name   type  \
# 797410                      About a Boy  2002  Hugh Grant  actor
# 797411                  American Dreamz  2006  Hugh Grant  actor
# 797432                 Music and Lyrics  2007  Hugh Grant  actor
# 797422  Did You Hear About the Morgans?  2009  Hugh Grant  actor
#
#             character    n
# 797410   Will Freeman  1.0
# 797411   Martin Tweed  1.0
# 797432  Alex Fletcher  1.0
# 797422    Paul Morgan  1.0

# %% [markdown]
# ### 2. Zaawansowane filtrowanie

# %%
c = titles
c[c.title.str.startswith('The')]
# Out:
#                                  title  year
# 2                       The Sonora Kid  1927
# 6                           The Banker  1989
# 10                      The Naked Cell  1988
# 23                      The Reason Why  1918
# 24                  The Flirting Widow  1930
# ...                                ...   ...
# 225980                   The Operative  2000
# 225984                The African Nazi  2013
# 225989  The Script: Beyond the Reality  2011
# 225994               The Christ Slayer  2018
# 226011                The Sandwich Man  1966
#
# [21486 rows x 2 columns]

# %%
titles.year.value_counts()
# Out:
# 2017    9888
# 2016    8198
# 2015    7564
# 2014    7159
# 2013    6896
#         ...
# 1894       1
# 1903       1
# 2026       1
# 1898       1
# 1899       1
# Name: year, Length: 128, dtype: int64

# %%
titles.year.value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
titles.year.value_counts().sort_index().plot()
# Out:
# <AxesSubplot:>

# %%
c = cast
c = c[c.character == 'Kermit the Frog']

# %%
c.plot(x='year',y='n',kind='scatter')
# Out:
# <AxesSubplot:xlabel='year', ylabel='n'>

# %% [markdown]
# ### Jakie jest dziesięć najczęstszych nazw filmów wszech czasów?

# %%
titles.title.value_counts().head(10)
# Out:
# Hamlet                  20
# Carmen                  17
# Macbeth                 16
# The Outsider            12
# The Three Musketeers    11
# Maya                    11
# Othello                 11
# Temptation              11
# Freedom                 11
# Kismet                  10
# Name: title, dtype: int64

# %% [markdown]
# ### W których trzech latach lat 30. XX wieku wydano najwięcej filmów?

# %%
t = titles
t = t[t.year // 10 == 193]
t.year.value_counts().head(3)
# Out:
# 1937    1217
# 1938    1161
# 1936    1153
# Name: year, dtype: int64

# %% [markdown]
# ### Stwórz wykres liczby filmów, które zostały wydane w każdej dekadzie w historii kina.

# %%
t = titles
(t.year // 10 * 10).value_counts().sort_index().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Wykreśl liczbę filmów "Hamlet" nakręconych w każdej dekadzie.

# %% [markdown]
# ### Jakie jest 11 najczęstszych imion postaci w historii filmu?

# %%
cast.character.value_counts().head(11)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 cast.character.value_counts().head(11)
#
# NameError: name 'cast' is not defined

# %% [markdown]
# ### Kim jest 10 osób najczęściej przypisywanych jako "Herself" w historii filmu?

# %% [markdown]
# ### Którzy aktorzy lub aktorki wystąpili w największej ilości filmów w roku 2010?

# %%
cast[cast.year == 2010].name.value_counts().head(10)
# Out:
# Brahmanandam            22
# Suraaj Venjarammoodu    21
# Jagathi Sreekumar       20
# Chris (II) Eddy         20
# Matt Simpson Siegel     17
# Salim Kumar             15
# Kyle Rea                15
# Danny Trejo             15
# Ben (II) Bishop         14
# Bijoy Mohanty           13
# Name: name, dtype: int64

# %% [markdown]
# ### Które aktorki wystąpiły w największej ilości filmów w roku 2015?

# %% [markdown]
# ### Stwórz wykres pokazujący ile ról Johnny Depp zagrał w poszczególnych latach swojej kariery.

# %% [markdown]
# ### Jakie jest 10 najczęściej występujących ról, które zaczynają się od frazy "Patron in"?

# %%
c = cast
c[c.character.str.startswith('Patron in ')].character.value_counts().head(10)
# Out:
# Patron in Frisky Rabbit         16
# Patron in the Coffee House       9
# Patron in Chinese Restaurant     9
# Patron in Billiard Parlor        5
# Patron in Bar                    4
# Patron in cabaret                3
# Patron in restaurant             3
# Patron in Restaurant             3
# Patron in Club                   3
# Patron in Coffee Shop            2
# dtype: int64

# %% [markdown]
# ### Jakie jest 10 najczęściej występujących ról, które zaczynają się od słowa "Science"?

# %% [markdown]
# ### Wyświetl n wartości ról jakie Leonardo DiCaprio otrzymał w swojej karierze

# %%
c = cast
c = c[c.name == 'Leonardo DiCaprio']
c.plot(x='year', y='n', kind='scatter')
# Out:
# <AxesSubplot:xlabel='year', ylabel='n'>

# %% [markdown]
# ### Ile ról pierwszoplanowych (n=1) było dostępnych dla aktorów, a ile dla aktorek, w latach 50. XX wieku?

# %%
c = cast

# %% [markdown]
# ### 3. Grupowanie

# %%
# Po co nam indexy ?

# Indexy organizuja nasze dane i sprawiają że możemy szybko dostać się do danych

# %%
len(cast)
# Out:
# 3442902

# %%
# %%time
cast[cast.title == 'Hamlet']
# Out:
# Wall time: 178 ms
#           title  year              name     type              character     n
# 1547     Hamlet  1996        Riz Abbasi    actor  Attendant to Claudius   1.0
# 7145     Hamlet  1921  Fritz Achterberg    actor            Fortinbras,   9.0
# 10751    Hamlet  2009      Hayden Adams    actor                Laertes   7.0
# 10752    Hamlet  2009      Hayden Adams    actor                 Player   7.0
# 13251    Hamlet  1913       Eric Adeney    actor               Reynaldo  14.0
# ...         ...   ...               ...      ...                    ...   ...
# 3341231  Hamlet  1969    Jennifer Tudor  actress             Court lady  23.0
# 3363189  Hamlet  2000      Diane Venora  actress               Gertrude   3.0
# 3391416  Hamlet  1996     Perdita Weeks  actress          Second Player  44.0
# 3395743  Hamlet  2015   Katie (II) West  actress                Ophelia   7.0
# 3411264  Hamlet  1996      Kate Winslet  actress                Ophelia  46.0
#
# [342 rows x 6 columns]

# %%
c = c.set_index('title')

# %%
# %%time
c.loc['Hamlet']
# Out:
# Wall time: 70.5 ms
#         year              name     type              character     n
# title
# Hamlet  1996        Riz Abbasi    actor  Attendant to Claudius   1.0
# Hamlet  1921  Fritz Achterberg    actor            Fortinbras,   9.0
# Hamlet  2009      Hayden Adams    actor                Laertes   7.0
# Hamlet  2009      Hayden Adams    actor                 Player   7.0
# Hamlet  1913       Eric Adeney    actor               Reynaldo  14.0
# ...      ...               ...      ...                    ...   ...
# Hamlet  1969    Jennifer Tudor  actress             Court lady  23.0
# Hamlet  2000      Diane Venora  actress               Gertrude   3.0
# Hamlet  1996     Perdita Weeks  actress          Second Player  44.0
# Hamlet  2015   Katie (II) West  actress                Ophelia   7.0
# Hamlet  1996      Kate Winslet  actress                Ophelia  46.0
#
# [342 rows x 5 columns]

# %%
c = cast
c = c.set_index('title').sort_index()

# %%
# %%time
c.loc['Hamlet']
# Out:
# Wall time: 660 µs
#         year               name     type                 character     n
# title
# Hamlet  2000       Sinead Dolan  actress  Special Guest Appearance  22.0
# Hamlet  2015          Ben Stott    actor                     Osric  12.0
# Hamlet  1996  Frank (II) Morgan    actor                   Pyrrhus   NaN
# Hamlet  1913        J.H. Barnes    actor                  Polonius   4.0
# Hamlet  2017  Russell (IV) Shaw    actor                   Horatio   NaN
# ...      ...                ...      ...                       ...   ...
# Hamlet  2015      John Shrapnel    actor                  Claudius   2.0
# Hamlet  1990    Stephen Dillane    actor                   Horatio   7.0
# Hamlet  1990     Barrie Holland    actor           Palace Nobleman   NaN
# Hamlet  1913       S.A. Cookson    actor                   Horatio   3.0
# Hamlet  1954           Jankidas    actor                     Osric   NaN
#
# [342 rows x 5 columns]

# %%
c = cast
c = c.set_index(['title','year']).sort_index()

# %%
c.loc['Hamlet',1990]
# Out:
#                              name     type  \
# title  year
# Hamlet 1990      Christien Anholt    actor
#        1990            Alan Bates    actor
#        1990           Justin Case    actor
#        1990       Stephen Dillane    actor
#        1990      Vernon Dobtcheff    actor
#        1990            Dave Duffy    actor
#        1990             Roy Evans    actor
#        1990  Christopher Fairbank    actor
#        1990            Mel Gibson    actor
#        1990        Barrie Holland    actor
#        1990              Ian Holm    actor
#        1990             Roger Low    actor
#        1990       Michael Maloney    actor
#        1990          John McEnery    actor
#        1990            Ned Mendez    actor
#        1990       Sean (V) Murray    actor
#        1990      Nathaniel Parker    actor
#        1990        Trevor Peacock    actor
#        1990    Pete Postlethwaite    actor
#        1990        Graham Riddell    actor
#        1990         Paul Scofield    actor
#        1990       Richard Warwick    actor
#        1990              Roy York    actor
#        1990         Marjorie Bell  actress
#        1990  Helena Bonham Carter  actress
#        1990           Glenn Close  actress
#        1990        Sarah Phillips  actress
#        1990   Baby Simon Sinclair  actress
#        1990       Pamela Sinclair  actress
#
#                                          character     n
# title  year
# Hamlet 1990                              Marcellus  14.0
#        1990                               Claudius   3.0
#        1990                            The Players  23.0
#        1990                                Horatio   7.0
#        1990                               Reynaldo  16.0
# Hamlet                               Gertrude   2.0
# Hamlet                            The Players  19.0
# Hamlet                            The Players  26.0
# Hamlet                            The Players  25.0

# %%
c.loc['Hamlet',1990].reset_index()
# Out:
#      title  year                  name     type  \
# 0   Hamlet  1990      Christien Anholt    actor
# 1   Hamlet  1990            Alan Bates    actor
# 2   Hamlet  1990           Justin Case    actor
# 3   Hamlet  1990       Stephen Dillane    actor
# 4   Hamlet  1990      Vernon Dobtcheff    actor
# 5   Hamlet  1990            Dave Duffy    actor
# 6   Hamlet  1990             Roy Evans    actor
# 7   Hamlet  1990  Christopher Fairbank    actor
# 8   Hamlet  1990            Mel Gibson    actor
# 9   Hamlet  1990        Barrie Holland    actor
# 10  Hamlet  1990              Ian Holm    actor
# 11  Hamlet  1990             Roger Low    actor
# 12  Hamlet  1990       Michael Maloney    actor
# 13  Hamlet  1990          John McEnery    actor
# 14  Hamlet  1990            Ned Mendez    actor
# 15  Hamlet  1990       Sean (V) Murray    actor
# 16  Hamlet  1990      Nathaniel Parker    actor
# 17  Hamlet  1990        Trevor Peacock    actor
# 18  Hamlet  1990    Pete Postlethwaite    actor
# 19  Hamlet  1990        Graham Riddell    actor
# 20  Hamlet  1990         Paul Scofield    actor
# 21  Hamlet  1990       Richard Warwick    actor
# 22  Hamlet  1990              Roy York    actor
# 23  Hamlet  1990         Marjorie Bell  actress
# 24  Hamlet  1990  Helena Bonham Carter  actress
# 25  Hamlet  1990           Glenn Close  actress
# 26  Hamlet  1990        Sarah Phillips  actress
# 27  Hamlet  1990   Baby Simon Sinclair  actress
# 28  Hamlet  1990       Pamela Sinclair  actress
#
#                                 character     n
# 0                               Marcellus  14.0
# 1                                Claudius   3.0
# 2                             The Players  23.0
# 3                                 Horatio   7.0
# 4                                Reynaldo  16.0
# 5                               Francisco  15.0
# 6                             The Players  27.0
# 7                            Player Queen  18.0
# 8                                  Hamlet   1.0
# 9                         Palace Nobleman   NaN
# 10                               Polonius   5.0
# 11  Lucianus (in "The Murder of Gonzago")  24.0
# 12                            Rosencrantz  10.0
# 13                                  Osric  12.0
# 14                            The Players  20.0
# 15                           Guildenstern   9.0
# 16                                Laertes   8.0
# 17                        The Gravedigger  11.0
# 18                            Player King  17.0
# 19                              Bodyguard   NaN
# 20                              The Ghost   4.0
# 21                               Bernardo  13.0
# 22                            The Players  21.0
# 23                            The Players  22.0
# 24                                Ophelia   6.0
# 25                               Gertrude   2.0
# 26                            The Players  19.0
# 27                            The Players  26.0
# 28                            The Players  25.0

# %%
c= cast
c = c[c.name == 'George Clooney']
c.groupby(['title','year','character']).size()
# Out:
# title                               year  character
# Batman & Robin                      1997  Batman                      1
#                                           Bruce Wayne                 1
# Burn After Reading                  2008  Harry Pfarrer               1
# Confessions of a Dangerous Mind     2002  Jim Byrd                    1
# Curdled                             1996  Seth Gecko                  1
# Fantastic Mr. Fox                   2009  Mr. Fox                     1
# Good Night, and Good Luck.          2005  Fred Friendly               1
# Gravity                             2013  Matt Kowalski               1
# Hail, Caesar!                       2016  Baird Whitlock              1
# Intolerable Cruelty                 2003  Miles                       1
# Leatherheads                        2008  Dodge Connelly              1
# Michael Clayton                     2007  Michael Clayton             1
# Money Monster                       2016  Lee Gates                   1
# Morning Glory                       2010  Himself                     1
# O Brother, Where Art Thou?          2000  Everett                     1
# Ocean's Eleven                      2001  Danny Ocean                 1
# Ocean's Thirteen                    2007  Danny Ocean                 1
# Ocean's Twelve                      2004  Danny Ocean                 1
# One Fine Day                        1996  Jack Taylor                 1
# Out of Sight                        1998  Jack Foley                  1
# Solaris                             2002  Chris Kelvin                1
# South Park: Bigger, Longer & Uncut  1999  Dr. Gouache                 1
# Spy Kids                            2001  Devlin                      1
# Spy Kids 3: Game Over               2003  Devlin                      1
# Syriana                             2005  Bob Barnes                  1
# The American                        2010  Edward                      1
#                                           Jack                        1
# The Book That Wrote Itself          1999  Himself                     1
# The Descendants                     2011  Matt King                   1
# The Good German                     2006  Jake Geismer                1
# The Harvest                         1992  Lip Syncing Transvestite    1
# The Ides of March                   2011  Governor Mike Morris        1
# The Limey                           1999  Himself                     1
# The Men Who Stare at Goats          2009  Lyn Cassady                 1
# The Monuments Men                   2014  Frank Stokes                1
# The Peacemaker                      1997  Lt. Col. Thomas Devoe       1
# The Perfect Storm                   2000  Billy Tyne                  1
# The Thin Red Line                   1998  Capt. Charles Bosche        1
# Three Kings                         1999  Archie Gates                1
# Tomorrowland                        2015  Frank Walker                1
# Unbecoming Age                      1992  Mac                         1
# Up in the Air                       2009  Ryan Bingham                1
# Welcome to Collinwood               2002  Jerzy                       1
# dtype: int64

# %%
c.groupby(['year']).size().plot(ylim=0,style='*')
# Out:
# <AxesSubplot:xlabel='year'>

# %%
c.groupby(['year']).n.max()
# Out:
# year
# 1992    23.0
# 1996     2.0
# 1997     2.0
# 1998    14.0
# 1999    11.0
# 2000     1.0
# 2001    36.0
# 2002    17.0
# 2003    22.0
# 2004     3.0
# 2005    15.0
# 2006     1.0
# 2007     6.0
# 2008     5.0
# 2009     1.0
# 2010     1.0
# 2011     2.0
# 2013     2.0
# 2014     1.0
# 2015     1.0
# 2016     2.0
# Name: n, dtype: float64

# %%
c.groupby(['year']).n.mean()
# Out:
# year
# 1992    14.000000
# 1996     2.000000
# 1997     1.666667
# 1998     7.500000
# 1999     6.000000
# 2000     1.000000
# 2001    18.500000
# 2002    11.000000
# 2003    11.500000
# 2004     3.000000
# 2005     8.500000
# 2006     1.000000
# 2007     3.500000
# 2008     3.000000
# 2009     1.000000
# 2010     1.000000
# 2011     1.500000
# 2013     2.000000
# 2014     1.000000
# 2015     1.000000
# 2016     1.500000
# Name: n, dtype: float64

# %%
c.groupby(c.year // 10 * 10).n.size()
# Out:
# year
# 1990    13
# 2000    20
# 2010    10
# Name: n, dtype: int64

# %% [markdown]
# ### Używając funkcji groupby(), pokaż na wykresie liczbę filmów, które zostały wydane w każdej dekadzie w historii kina.

# %%
t = titles

# %% [markdown]
# ### Użyj groupby(), pokaż na wykresie liczbę filmów o "Hamlecie" nakręconych w każdej dekadzie.

# %%
t = titles

# %% [markdown]
# ### Ile ról pierwszoplanowych (n=1) mieli do dyspozycji aktorzy, a ile aktorki, w każdym roku lat pięćdziesiątych?

# %%
c = cast
c = c[c.year // 10 == 195]
c = c[c.n == 1]
c.groupby(['year', 'type']).size()
# Out:
# year  type
# 1950  actor      603
#       actress    267
# 1951  actor      626
#       actress    272
# 1952  actor      590
#       actress    282
# 1953  actor      629
#       actress    283
# 1954  actor      620
#       actress    298
# 1955  actor      602
#       actress    263
# 1956  actor      609
#       actress    284
# 1957  actor      703
#       actress    281
# 1958  actor      695
#       actress    273
# 1959  actor      672
#       actress    286
# dtype: int64

# %% [markdown]
# ### Wymień, w kolejności według roku, każdy z filmów, w których Frank Oz zagrał więcej niż 1 rolę.

# %%
c = cast
c = c[c.name == 'Frank Oz']
g = c.groupby(['year', 'title']).size()
g[g > 1]
# Out:
# year  title
# 1979  The Muppet Movie                        8
# 1981  The Great Muppet Caper                  6
# 1982  The Dark Crystal                        2
# 1984  The Muppets Take Manhattan              7
# 1985  Follow That Bird                        3
# 1992  The Muppet Christmas Carol              7
# 1996  Muppet Treasure Island                  4
# 1999  Muppets from Space                      4
#       The Adventures of Elmo in Grouchland    3
# dtype: int64

# %% [markdown]
# ### Użyj groupby(), aby określić, ile ról jest wymienionych dla każdego filmu o nazwie _Różowa Pantera_.

# %%
c = cast
c = c[c.title == 'The Pink Panther']
c = c.sort_values('n').groupby(['year']).n.max()
c
# Out:
# year
# 1963    15.0
# 2006    50.0
# Name: n, dtype: float64

# %% [markdown]
# ### Wymień każdą z postaci, którą Frank Oz zagrał przynajmniej dwa razy.

# %%
c = cast
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 3>()
#       1 ### Wymień każdą z postaci, którą Frank Oz zagrał przynajmniej dwa razy.
# ----> 3 c = cast
#
# NameError: name 'cast' is not defined

# %% [markdown]
# ### 4. Zaawansowane grupowanie

# %%
c = cast

c = c[(c.character == 'Kermit the Frog') | (c.character == 'Oscar the Grouch')]
g = c.groupby(['character',c.year//10*10]).size() # Ciężko porównać te dane
g
# Out:
# character         year
# Kermit the Frog   1970    1
#                   1980    3
#                   1990    2
#                   2000    1
#                   2010    1
# Oscar the Grouch  1980    2
#                   1990    1
#                   2000    1
# dtype: int64

# %%
u = g.unstack()
u
# Out:
# year              1970  1980  1990  2000  2010
# character
# Kermit the Frog    1.0   3.0   2.0   1.0   1.0
# Oscar the Grouch   NaN   2.0   1.0   1.0   NaN

# %%
u.stack()
# Out:
# character         year
# Kermit the Frog   1970    1.0
#                   1980    3.0
#                   1990    2.0
#                   2000    1.0
#                   2010    1.0
# Oscar the Grouch  1980    2.0
#                   1990    1.0
#                   2000    1.0
# dtype: float64

# %%
u = g.unstack().T
u
# Out:
# character  Kermit the Frog  Oscar the Grouch
# year
# 1970                   1.0               NaN
# 1980                   3.0               2.0
# 1990                   2.0               1.0
# 2000                   1.0               1.0
# 2010                   1.0               NaN

# %%
u['Kermit the Frog'] - u['Oscar the Grouch'] ## BRAKUJE DANYCH !
# Out:
# year
# 1970    NaN
# 1980    1.0
# 1990    1.0
# 2000    0.0
# 2010    NaN
# dtype: float64

# %%
u = u.fillna(0) # Można dać cokolwiek
u
# Out:
# character  Kermit the Frog  Oscar the Grouch
# year
# 1970                   1.0               0.0
# 1980                   3.0               2.0
# 1990                   2.0               1.0
# 2000                   1.0               1.0
# 2010                   1.0               0.0

# %%
u['Kermit the Frog'] - u['Oscar the Grouch'] ## BRAKUJE DANYCH !
# Out:
# year
# 1970    1.0
# 1980    1.0
# 1990    1.0
# 2000    0.0
# 2010    1.0
# dtype: float64

# %% [markdown]
# ### Zdefiniuj rok jako "rok Supermana". W których filmach pojawia się więcej postaci Supermana niż Batmana. Ile lat w historii filmu było latami Supermana?

# %%
c = cast
c = c[(c.character == 'Superman') | (c.character == 'Batman')]
c = c.groupby(['year', 'character']).size()
c = c.unstack()
c = c.fillna(0)
c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 c = cast
#       2 c = c[(c.character == 'Superman') | (c.character == 'Batman')]
#       3 c = c.groupby(['year', 'character']).size()
#
# NameError: name 'cast' is not defined

# %%
# Lata supermana

# %%
# Lata Batmana

# %% [markdown]
# ### Stwórz wykres liczby ról aktorów i aktorek w każdym roku.

# %%
c = cast
c = c.groupby(['year', 'type']).size()
c = c.unstack('type')
c.plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# ### Stwórz wykres liczby ról aktorów i aktorek w każdym roku. Wykorzystaj rodzaj wykresu "area".

# %%
c = cast

# %% [markdown]
# ### Pokaż na wykresie różnicę między liczbą ról męskich i żeńskich.

# %% [markdown]
# ### Pokaż na wykresie stosunek liczby ról męskich i żeńskich to ogółu ról.

# %%
c = cast

# %% [markdown]
# ### Pokaż na wykresie stosunek liczby ról męskich drugoplanowych do ogółu ról w historii kina.

# %% [markdown]
# ### Pokaż wykres liniowy dla każdej n od n=1 do n=3, gdzie linia pokazuje, jaka część ról tego n była rolami męskimi.

# %%
c = cast
c = c[c.n <= 3]
c = c.groupby(['year', 'type', 'n']).size()
c = c.unstack('type').fillna(0)
r = c.actor / (c.actor + c.actress)
r = r.unstack('n')
r.plot(ylim=[0,1])
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# ### 5. Łączenie danych

# %%
release_dates = pd.read_csv('data/release_dates.csv', 
                                      parse_dates=['date'], infer_datetime_format=True)
release_dates.head()
# Out:
#                     title  year      country       date
# 0   #73, Shaanthi Nivaasa  2007        India 2007-06-15
# 1                   #BKKY  2016     Cambodia 2017-10-12
# 2                 #Beings  2015      Romania 2015-01-29
# 3               #Captured  2017          USA 2017-09-05
# 4  #Ewankosau saranghaeyo  2015  Philippines 2015-01-21

# %%
r = release_dates
r.date.dt.year
# Out:
# 0         2007
# 1         2017
# 2         2015
# 3         2017
# 4         2015
#           ...
# 443481    2005
# 443482    2005
# 443483    2005
# 443484    2005
# 443485    2005
# Name: date, Length: 443486, dtype: int64

# %%
c = cast
c = c[c.name == 'Ellen Page']
c
# Out:
#                                                      title  year        name  \
# 3047083                                  An American Crime  2007  Ellen Page
# 3047084                                           Freeheld  2015  Ellen Page
# title
# Star Wars: Episode I - The Phantom Menace      1999-07-02 1999-06-30
# Star Wars: Episode II - Attack of the Clones   2002-07-05 2002-07-03
# Star Wars: Episode III - Revenge of the Sith   2005-05-18        NaT
# Star Wars: Episode IX                                 NaT        NaT
# Star Wars: Episode V - The Empire Strikes Back 1981-01-15        NaT
# Star Wars: Episode VI - Return of the Jedi     1984-01-01        NaT
# Star Wars: Episode VII - The Force Awakens     2015-12-17 2015-12-18
# Star Wars: Episode VIII - The Last Jedi        2017-12-14        NaT
#
# country                                           Vietnam West Germany
# title
# Star Wars: Episode I - The Phantom Menace             NaT          NaT
# Star Wars: Episode II - Attack of the Clones          NaT          NaT
# Star Wars: Episode III - Revenge of the Sith          NaT          NaT
# Star Wars: Episode IX                                 NaT          NaT
# Star Wars: Episode V - The Empire Strikes Back        NaT   1980-12-11
# Star Wars: Episode VI - Return of the Jedi            NaT   1983-12-09
# Star Wars: Episode VII - The Force Awakens     2015-12-18          NaT
# Star Wars: Episode VIII - The Last Jedi        2017-12-15          NaT
#
# [8 rows x 105 columns]

# %%
# merge dwóch tabel z jednej tabeli (z kim Cary Grant grał główne role?)

c = cast
c = c[c.n <=2]
c = c[c.name == 'Cary Grant']
c.head()
# Out:
#                         title  year        name   type          character    n
# 790040  An Affair to Remember  1957  Cary Grant  actor    Nickie Ferrante  1.0
# 790041   Arsenic and Old Lace  1944  Cary Grant  actor  Mortimer Brewster  1.0
# 790042         Big Brown Eyes  1936  Cary Grant  actor         Danny Barr  1.0
# 790044         Born to Be Bad  1934  Cary Grant  actor     Malcolm Trevor  2.0
# 790045       Bringing Up Baby  1938  Cary Grant  actor              David  2.0

# %%
c = c.merge(cast,on=['title','year'])
c = c[c.n_y <=2]
c = c[c.name_y != 'Cary Grant']
c[['title','year','name_x','name_y']].sort_values('year')
# Out:
#                        title  year      name_x          name_y
# 1099        Madame Butterfly  1932  Cary Grant   Sylvia Sidney
# 765             Hot Saturday  1932  Cary Grant   Nancy Carroll
# 2224      She Done Him Wrong  1933  Cary Grant        Mae West
# 2538  The Eagle and the Hawk  1933  Cary Grant   Fredric March
# 914             I'm No Angel  1933  Cary Grant        Mae West
# ...                      ...   ...         ...             ...
# 2557    The Grass Is Greener  1960  Cary Grant    Deborah Kerr
# 2364      That Touch of Mink  1962  Cary Grant       Doris Day
# 304                  Charade  1963  Cary Grant  Audrey Hepburn
# 608             Father Goose  1964  Cary Grant    Leslie Caron
# 3132          Walk Don't Run  1966  Cary Grant  Samantha Eggar
#
# [68 rows x 4 columns]

# %% [markdown]
# ### Wykonaj wykres słupkowy miesięcy, w których filmy z "Christmas" w tytule ukazują się w USA.

# %%
rd = release_dates
rd = rd[rd.title.str.contains('Christmas')]
rd = rd[rd.country == 'USA']
rd.date.dt.month.value_counts().sort_index().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Zrób wykres słupkowy dnia tygodnia, w którym filmy z "Action" w tytule ukazują się w USA.

# %%
rd = release_dates

# %% [markdown]
# ### W których miesiącach filmy z Tomem Cruise'em najczęściej trafiają do kin w USA?

# %%
c = cast
